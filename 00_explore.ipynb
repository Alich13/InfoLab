# %%
import pandas as pd
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("/Users/alichemkhi/Desktop/myProjects/InfoLab/datasym/extraction_contrats.xlsx")
# Out:
# /Users/alichemkhi/miniconda3/envs/streamlit-env/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df["Date Création"] = pd.to_datetime(df["Date Création"], format="%d/%m/%Y")

# %%
df_filtered=df[df["Service"]=="DRV FSI développement"]
df_filtered
# Out:
#                Createur Date Création                Service  \
# 0          Enric THOMAS    2025-02-11  DRV FSI développement
# 1        Alice JANNIAUD    2025-02-11  DRV FSI développement
# 2      Alexandre MENARD    2025-02-11  DRV FSI développement
# 3      Chloé GRANDO-GAI    2025-02-11  DRV FSI développement
# 4        Hugo LE GARREC    2025-02-11  DRV FSI développement
# ...                 ...           ...                    ...
# 23752     Anaïs DESCLOS    2014-02-21  DRV FSI développement
# 23754   Annabelle OSTYN    2014-02-17  DRV FSI développement
# 23755      Amélie GREGO    2014-02-17  DRV FSI développement
# 23756    Marlene AFONSO    2014-02-12  DRV FSI développement
# 23759   Annabelle OSTYN    2014-02-03  DRV FSI développement
#
#       Contact princpal DR&I  \
# 0              Enric THOMAS
# 1            Alice JANNIAUD
# 2          Alexandre MENARD
# 3          Chloé GRANDO-GAI
# 4            Hugo LE GARREC
# ...                     ...
# 23752         Anaïs DESCLOS
# 23754       Annabelle OSTYN
# 23755          Amélie GREGO
# 23756        Marlene AFONSO
# 23759       Annabelle OSTYN
#
#                                            Contacts DR&I Numero projet  \
# 0                                           Enric THOMAS      P24/0956
# 1                                         Alice JANNIAUD      P22/0030
# 2                                       Alexandre MENARD      P25/0182
# 3                       Nicole PARIS // Chloé GRANDO-GAI      P25/0181
# 4                                         Hugo LE GARREC      P25/0180
# ...                                                  ...           ...
# 23752                   Anaïs DESCLOS // Susanna PARENTI      P14/0015
# 23754  Annabelle OSTYN // Albena SAYNOVA // Rosaly DA...      P14/0014
# 23755   Amélie GREGO // Tassadit TABET // Emilie PORCHER      P14/0012
# 23756                                     Marlene AFONSO      P14/0009
# 23759  Odile CYPRIA // Annabelle OSTYN // Lucie SALVA...      P14/0004
#
#                                          Intitule projet  \
# 0      Design of original Silicon-based multielement ...
# 1      Contrôle quantique performante des rotations m...
# 2      Fourier methods for a Eulerian-based contact m...
# 3                        NDA avec Multinationale Corning
# 4                              CIFRE_Withings_INRIA_LPSM
# ...                                                  ...
# 23752  Coherent Information Processing in Rare-earth ...
# 23754  Aerobiological information systems and allergi...
# 23755  Base de Connaisances sur le Systeme Sensoriel ...
# 23756  Implementation et validation instrumentale a o...
# 23759                                    med-hiss Life +
#
#                                 Acronyme                  Type projet  \
# 0                                SILICOR        Activité de recherche
# 1                                 CoRoMo        Activité de recherche
# 2      Convention d'accueil Flavio Lorez        Activité de recherche
# 3                                  néant        Activité de recherche
# 4                                  CIFRE  Mission formation recherche
# ...                                  ...                          ...
# 23752                             CIPRIS        Activité de recherche
# 23754                                AIS        Activité de recherche
# 23755                     KBaSS - ViSIOn        Activité de recherche
# 23756                          PARACI-MS               Infrastructure
# 23759                            Medhiss        Activité de recherche
#
#       Cadre de financement  ...  \
# 0           Horizon Europe  ...
# 1            ANR opérateur  ...
# 2              Autre cadre  ...
# 3                      NaN  ...
# 4                     ANRT  ...
# ...                    ...  ...
# 23752                  FP7  ...
# 23754             Hors FP7  ...
# 23755          Autre cadre  ...
# 23756                  DIM  ...
# 23759             Hors FP7  ...
#
#                                            Acteurs::Type  \
# 0                            Organisation Internationale
# 1      Recherche publique // Collectivités territoriales
# 2                                     Recherche publique
# 3                                            Entreprises
# 4                      Recherche publique // Entreprises
# ...                                                  ...
# 23752  Recherche publique // Organisation Internation...
# 23754  Recherche publique // Organisation Internation...
# 23755                     Institutions sans but lucratif
# 23756  Collectivités territoriales // Recherche publi...
# 23759  Recherche publique // Organisation Internation...
#
#                                       Acteurs::Sous-type  \
# 0                                  Commission européenne
# 1            Opérateurs de recherche // Conseil régional
# 2                                Opérateurs de recherche
# 3      Grandes entreprises, Plus de 1500 millions d'€...
# 4      Opérateurs de recherche // Petites et moyennes...
# ...                                                  ...
# 23752  Opérateurs de recherche // Commission européen...
# 23754  Opérateurs de recherche // Commission européen...
# 23755                    Fondation à vocation caritative
# 23756  Conseil régional // Opérateurs de recherche //...
# 23759  Opérateurs de recherche // Commission européen...
#
#                                          Acteurs::Classe  \
# 0                                                    NaN
# 1      Organismes de recherche à but non lucratif (EP...
# 2                                            UNIVERSITE
# 3                                                    NaN
# 4      Organismes de recherche à but non lucratif (EP...
# ...                                                  ...
# 23752  Organismes de recherche à but non lucratif (EP...
# 23754  Organismes de recherche à but non lucratif (EP...
# 23755                                                NaN
# 23756  null // Organismes de recherche à but non lucr...
# 23759  Organismes de recherche à but non lucratif (EP...
#
#                                            Acteurs::Pays  \
# 0                                               Belgique
# 1                                       France // France
# 2                                                 SUISSE
# 3                                                 France
# 4                                       France // France
# ...                                                  ...
# 23752                       France // Belgique // France
# 23754  France // Belgique // ITALIE // ITALIE // ITAL...
# 23755                                             France
# 23756                         France // France // France
# 23759  France // Belgique // ITALIE // ESPAGNE // ITA...
#
#                                 Financeurs::Dénomination  \
# 0                                  Commission Européenne
# 1                         CONSEIL REGIONAL ILE DE FRANCE
# 2                                                    NaN
# 3                                                    NaN
# 4                                               Withings
# ...                                                  ...
# 23752                              Commission Européenne
# 23754                              Commission Européenne
# 23755                       Fondation Recherche Medicale
# 23756  CONSEIL REGIONAL ILE DE FRANCE // Institut Nat...
# 23759                              Commission Européenne
#
#            Financeurs::Sigle  \
# 0      Commission Européenne
# 1                     CR IdF
# 2                        NaN
# 3                        NaN
# 4                   Withings
# ...                      ...
# 23752  Commission Européenne
# 23754  Commission Européenne
# 23755                    FRM
# 23756  CR IdF // INRAE // SU
# 23759  Commission Européenne
#
#                                         Financeurs::Type  \
# 0                            Organisation Internationale
# 1                            Collectivités territoriales
# 2                                                    NaN
# 3                                                    NaN
# 4                                            Entreprises
# ...                                                  ...
# 23752                        Organisation Internationale
# 23754                        Organisation Internationale
# 23755                     Institutions sans but lucratif
# 23756  Collectivités territoriales // Recherche publi...
# 23759                        Organisation Internationale
#
#                                    Financeurs::Sous-type  \
# 0                                  Commission européenne
# 1                                       Conseil régional
# 2                                                    NaN
# 3                                                    NaN
# 4      Petites et moyennes entreprises (PME), Moins d...
# ...                                                  ...
# 23752                              Commission européenne
# 23754                              Commission européenne
# 23755                    Fondation à vocation caritative
# 23756  Conseil régional // Opérateurs de recherche //...
# 23759                              Commission européenne
#
#                                       Financeurs::Classe  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 23752                                                NaN
# 23754                                                NaN
# 23755                                                NaN
# 23756  null // Organismes de recherche à but non lucr...
# 23759                                                NaN
#
#                  Financeurs::Pays
# 0                        Belgique
# 1                          France
# 2                             NaN
# 3                             NaN
# 4                          France
# ...                           ...
# 23752                    Belgique
# 23754                    Belgique
# 23755                      France
# 23756  France // France // France
# 23759                    Belgique
#
# [15260 rows x 51 columns]

# %%
actor_list = [ str(x).split("//") for x in list(df_filtered["Acteurs::Type"])]
my_list =[]
for i in actor_list:
    my_list.extend(i)

uniqlist=set([x.strip() for x in my_list])

uniqlist
# Out:
# {'Collectivités territoriales',
#  'Entreprises',
#  'Institutions sans but lucratif',
#  'Organisation Internationale',
#  'Recherche publique',
#  'nan'}

# %%
df_filtered["Numero contrat"].value_counts()

column_to_explode = 'Acteurs::Dénomination'
target_name="Unité"

contract_actors = df_filtered[['Numero contrat', column_to_explode]].copy()
contract_actors[column_to_explode] = contract_actors[column_to_explode].str.split(' // ')
contract_actors = contract_actors.explode(column_to_explode)
contract_actors[column_to_explode] = contract_actors[column_to_explode].str.strip()
contract_actors=contract_actors.rename(columns={'Acteurs::Dénomination': target_name})
contract_actors
# Out:
#       Numero contrat                                              Unité
# 0           C25/0289                              Commission Européenne
# 1           C25/0288       Centre national de la recherche scientifique
# 1           C25/0288                     CONSEIL REGIONAL ILE DE FRANCE
# 2           C25/0287       EIDGENOESSISCHE TECHNISCHE HOCHSCHULE ZURICH
# 3           C25/0286                                        CORNING SAS
# ...              ...                                                ...
# 23759       C14/0003                              Commission Européenne
# 23759       C14/0003                                      ARPA PIEMONTE
# 23759       C14/0003       Centre de Recerca en Epidemiologia Ambiental
# 23759       C14/0003  Italian National Agency for New Technologies, ...
# 23759       C14/0003                National Institute of Public Health
#
# [27453 rows x 2 columns]

# %%
df_filtered[df_filtered["Numero contrat"]=="C14/0003"]["Acteurs::Dénomination"].values
# Out:
# array(['INSTITUT NATIONAL DE LA SANTE  ET DE LA RECHERCHE MEDICALE // Commission Européenne // ARPA PIEMONTE // Centre de Recerca en Epidemiologia Ambiental  // Italian National Agency for New Technologies, Energy and Sustainable\rEconomic Development // National Institute of Public Health'],
#       dtype=object)

# %%
df_filtered=df_filtered[df_filtered["Outil du cadre"].isin(["CDDP","CIFRE"])]
occurences = df_filtered.groupby(["Outil du cadre","Phase"]).size().reset_index(name="Count")
occurences
st.bar_chart(occurences, x="Outil du cadre", y="Count", color="Phase", horizontal=True)
# Out:
# 2025-03-06 15:09:53.858 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-06 15:09:53.859 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
occurences.reset_index()
occurences
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/75/35r72_cx7h71d1114xgc6qv40000gn/T/ipykernel_1686/3454430820.py in ?()
# ----> 1 occurences.reset_index()
#       2 occurences
#
# ~/miniconda3/envs/streamlit-env/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6468                     level_values = algorithms.take(
#    6469                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6470                     )
#    6471
# -> 6472                 new_obj.insert(
#    6473                     0,
#    6474                     name,
#    6475                     level_values,
#
# ~/miniconda3/envs/streamlit-env/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#    5161         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert Phase, already exists

# %%
occurences = df_filtered.groupby("Date Création").size()
# barplot
fig, ax = plt.subplots()
occurences.plot(kind="bar", ax=ax)
plt.xticks(rotation=45)
# plot the bar chart in jupyther
st.pyplot(fig)
# Out:
# 2025-03-05 21:19:12.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-05 21:19:14.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-05 21:19:14.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
value_counts = df['Financeurs::Pays'].value_counts()
filtered_df = df[df['Financeurs::Pays'].isin(value_counts[value_counts > 10].index)]
filtered_df
# Out:
#                        Createur Date Création                     Service  \
# 0                  Enric THOMAS    2025-02-11       DRV FSI développement
# 1                Alice JANNIAUD    2025-02-11       DRV FSI développement
# 4                Hugo LE GARREC    2025-02-11       DRV FSI développement
# 5                  Enric THOMAS    2025-02-11       DRV FSI développement
# 7              Alexandre MENARD    2025-02-11       DRV FSI développement
# ...                         ...           ...                         ...
# 23755              Amélie GREGO    2014-02-17       DRV FSI développement
# 23756            Marlene AFONSO    2014-02-12       DRV FSI développement
# 23758                Ana BOBIER    2014-02-10  DRV Médecine développement
# 23759           Annabelle OSTYN    2014-02-03       DRV FSI développement
# 23760  Géraldine BLEMAND-JEANNE    2014-01-30    DRV FSI aide au pilotage
#
#           Contact princpal DR&I  \
# 0                  Enric THOMAS
# 1                Alice JANNIAUD
# 4                Hugo LE GARREC
# 5                  Enric THOMAS
# 7              Alexandre MENARD
# ...                         ...
# 23755              Amélie GREGO
# 23756            Marlene AFONSO
# 23758                Ana BOBIER
# 23759           Annabelle OSTYN
# 23760  Géraldine BLEMAND-JEANNE
#
#                                            Contacts DR&I Numero projet  \
# 0                                           Enric THOMAS      P24/0956
# 1                                         Alice JANNIAUD      P22/0030
# 4                                         Hugo LE GARREC      P25/0180
# 5                                           Enric THOMAS      P24/0945
# 7                                       Alexandre MENARD      P23/0978
# ...                                                  ...           ...
# 23755   Amélie GREGO // Tassadit TABET // Emilie PORCHER      P14/0012
# 23756                                     Marlene AFONSO      P14/0009
# 23758  Odile CYPRIA // Ana BOBIER // Meryem YALBIR //...      P14/0006
# 23759  Odile CYPRIA // Annabelle OSTYN // Lucie SALVA...      P14/0004
# 23760  Géraldine BLEMAND-JEANNE // Meryem YALBIR // E...      P14/0001
#
#                                          Intitule projet        Acronyme  \
# 0      Design of original Silicon-based multielement ...         SILICOR
# 1      Contrôle quantique performante des rotations m...          CoRoMo
# 4                              CIFRE_Withings_INRIA_LPSM           CIFRE
# 5      Understanding the molecular mechanisms enablin...        EPICORAL
# 7      Harnessing snap-through transition waves in mu...         SnaPump
# ...                                                  ...             ...
# 23755  Base de Connaisances sur le Systeme Sensoriel ...  KBaSS - ViSIOn
# 23756  Implementation et validation instrumentale a o...       PARACI-MS
# 23758                       Effet du V55 sur les plantes             NaN
# 23759                                    med-hiss Life +         Medhiss
# 23760                                     PIA - HEPATHER        HEPATHER
#
#                        Type projet Cadre de financement  ...  \
# 0            Activité de recherche       Horizon Europe  ...
# 1            Activité de recherche        ANR opérateur  ...
# 4      Mission formation recherche                 ANRT  ...
# 5            Activité de recherche       Horizon Europe  ...
# 7            Activité de recherche       Horizon Europe  ...
# ...                            ...                  ...  ...
# 23755        Activité de recherche          Autre cadre  ...
# 23756               Infrastructure                  DIM  ...
# 23758       Activité de prestation                  NaN  ...
# 23759        Activité de recherche             Hors FP7  ...
# 23760               Infrastructure                  PIA  ...
#
#                                            Acteurs::Type  \
# 0                            Organisation Internationale
# 1      Recherche publique // Collectivités territoriales
# 4                      Recherche publique // Entreprises
# 5      Organisation Internationale // Recherche publique
# 7                            Organisation Internationale
# ...                                                  ...
# 23755                     Institutions sans but lucratif
# 23756  Collectivités territoriales // Recherche publi...
# 23758                                        Entreprises
# 23759  Recherche publique // Organisation Internation...
# 23760  Recherche publique // Recherche publique // Re...
#
#                                       Acteurs::Sous-type  \
# 0                                  Commission européenne
# 1            Opérateurs de recherche // Conseil régional
# 4      Opérateurs de recherche // Petites et moyennes...
# 5       Commission européenne // Opérateurs de recherche
# 7                                  Commission européenne
# ...                                                  ...
# 23755                    Fondation à vocation caritative
# 23756  Conseil régional // Opérateurs de recherche //...
# 23758  Grandes entreprises, Plus de 1500 millions d'€...
# 23759  Opérateurs de recherche // Commission européen...
# 23760  Opérateurs de recherche // Agences // Agences ...
#
#                                          Acteurs::Classe  \
# 0                                                    NaN
# 1      Organismes de recherche à but non lucratif (EP...
# 4      Organismes de recherche à but non lucratif (EP...
# 5                                    null // UNIVERSITE
# 7                                                    NaN
# ...                                                  ...
# 23755                                                NaN
# 23756  null // Organismes de recherche à but non lucr...
# 23758                                                NaN
# 23759  Organismes de recherche à but non lucratif (EP...
# 23760  Organismes de recherche à but non lucratif (EP...
#
#                                            Acteurs::Pays  \
# 0                                               Belgique
# 1                                       France // France
# 4                                       France // France
# 5                                     Belgique // France
# 7                                               Belgique
# ...                                                  ...
# 23755                                             France
# 23756                         France // France // France
# 23758                                             France
# 23759  France // Belgique // ITALIE // ESPAGNE // ITA...
# 23760             France // France // France // Belgique
#
#                                 Financeurs::Dénomination  \
# 0                                  Commission Européenne
# 1                         CONSEIL REGIONAL ILE DE FRANCE
# 4                                               Withings
# 5                                  Commission Européenne
# 7                                  Commission Européenne
# ...                                                  ...
# 23755                       Fondation Recherche Medicale
# 23756  CONSEIL REGIONAL ILE DE FRANCE // Institut Nat...
# 23758                                           LESAFFRE
# 23759                              Commission Européenne
# 23760  Agence Nationale de la Recherche // AGENCE NAT...
#
#            Financeurs::Sigle  \
# 0      Commission Européenne
# 1                     CR IdF
# 4                   Withings
# 5      Commission Européenne
# 7      Commission Européenne
# ...                      ...
# 23755                    FRM
# 23756  CR IdF // INRAE // SU
# 23758               LESAFFRE
# 23759  Commission Européenne
# 23760            ANR // ANRS
#
#                                         Financeurs::Type  \
# 0                            Organisation Internationale
# 1                            Collectivités territoriales
# 4                                            Entreprises
# 5                            Organisation Internationale
# 7                            Organisation Internationale
# ...                                                  ...
# 23755                     Institutions sans but lucratif
# 23756  Collectivités territoriales // Recherche publi...
# 23758                                        Entreprises
# 23759                        Organisation Internationale
# 23760           Recherche publique // Recherche publique
#
#                                    Financeurs::Sous-type  \
# 0                                  Commission européenne
# 1                                       Conseil régional
# 4      Petites et moyennes entreprises (PME), Moins d...
# 5                                  Commission européenne
# 7                                  Commission européenne
# ...                                                  ...
# 23755                    Fondation à vocation caritative
# 23756  Conseil régional // Opérateurs de recherche //...
# 23758  Grandes entreprises, Plus de 1500 millions d'€...
# 23759                              Commission européenne
# 23760                                 Agences // Agences
#
#                                       Financeurs::Classe  \
# 0                                                    NaN
# 1                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 7                                                    NaN
# ...                                                  ...
# 23755                                                NaN
# 23756  null // Organismes de recherche à but non lucr...
# 23758                                                NaN
# 23759                                                NaN
# 23760  en charge de la recherche // en charge de la r...
#
#                  Financeurs::Pays
# 0                        Belgique
# 1                          France
# 4                          France
# 5                        Belgique
# 7                        Belgique
# ...                           ...
# 23755                      France
# 23756  France // France // France
# 23758                      France
# 23759                    Belgique
# 23760            France // France
#
# [15116 rows x 51 columns]

# %%
import plotly.express as px
df_filtered=df_filtered[df_filtered["Outil du cadre"].isin(["CDDP","CIFRE"])]
occurences = df_filtered.groupby(["Outil du cadre","Phase"]).agg({"Phase": "count"})

switch_dict={
    "FRANCE // FRANCE" :"FRANCE",
    "FRANCE // FRANCE // FRANCE" : "FRANCE"
}

filtered_df["Financeurs::Pays"]
filtered_df["Pays"]=filtered_df["Financeurs::Pays"].map( lambda x : x.strip().upper() )
filtered_df["Pays"]=filtered_df["Pays"].map( lambda x : switch_dict[x] if x in switch_dict.keys() else x  )
filtered_df["Pays"].value_counts()


# Count occurrences of each Category
grouped_df = filtered_df["Pays"].value_counts().reset_index()
grouped_df.columns = ["Pays", "Count"]  # Rename columns
grouped_df

fig = px.pie(grouped_df, names="Pays", values="Count", 
             title="distribution par pays", 
             hole=0.4,  # Makes it a donut chart (set to 0 for a full pie)
             color_discrete_sequence=px.colors.qualitative.Set2)

# Show the plot in Jupyter Notebook
fig.show()
# Out:
# /var/folders/75/35r72_cx7h71d1114xgc6qv40000gn/T/ipykernel_1686/3438288269.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["Pays"]=filtered_df["Financeurs::Pays"].map( lambda x : x.strip().upper() )
# /var/folders/75/35r72_cx7h71d1114xgc6qv40000gn/T/ipykernel_1686/3438288269.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["Pays"]=filtered_df["Pays"].map( lambda x : switch_dict[x] if x in switch_dict.keys() else x  )
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 27
#      21 fig = px.pie(grouped_df, names="Pays", values="Count",
#      22              title="distribution par pays",
#      23              hole=0.4,  # Makes it a donut chart (set to 0 for a full pie)
#      24              color_discrete_sequence=px.colors.qualitative.Set2)
#      26 # Show the plot in Jupyter Notebook
# ---> 27 fig.show()
#
# File ~/miniconda3/envs/streamlit-env/lib/python3.10/site-packages/plotly/basedatatypes.py:3414, in BaseFigure.show(self, *args, **kwargs)
#    3381 """
#    3382 Show a figure using either the default renderer(s) or the renderer(s)
#    3383 specified by the renderer argument
#    (...)
#    3410 None
#    3411 """
#    3412 import plotly.io as pio
# -> 3414 return pio.show(self, *args, **kwargs)
#
# File ~/miniconda3/envs/streamlit-env/lib/python3.10/site-packages/plotly/io/_renderers.py:425, in show(fig, renderer, validate, **kwargs)
#     420     raise ValueError(
#     421         "Mime type rendering requires ipython but it is not installed"
#     422     )
#     424 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 425     raise ValueError(
#     426         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     427     )
#     429 display_jupyter_version_warnings()
#     431 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %%
df["Year"] = df["Date Création"].dt.year.astype(str)
df
# Out:
#                        Createur Date Création                     Service  \
# 0                  Enric THOMAS    2025-02-11       DRV FSI développement
# 1                Alice JANNIAUD    2025-02-11       DRV FSI développement
# 2              Alexandre MENARD    2025-02-11       DRV FSI développement
# 3              Chloé GRANDO-GAI    2025-02-11       DRV FSI développement
# 4                Hugo LE GARREC    2025-02-11       DRV FSI développement
# ...                         ...           ...                         ...
# 23757                Ana BOBIER    2014-02-11  DRV Médecine développement
# 23758                Ana BOBIER    2014-02-10  DRV Médecine développement
# 23759           Annabelle OSTYN    2014-02-03       DRV FSI développement
# 23760  Géraldine BLEMAND-JEANNE    2014-01-30    DRV FSI aide au pilotage
# 23761                Ana BOBIER    2014-01-30  DRV Médecine développement
#
#           Contact princpal DR&I  \
# 0                  Enric THOMAS
# 1                Alice JANNIAUD
# 2              Alexandre MENARD
# 3              Chloé GRANDO-GAI
# 4                Hugo LE GARREC
# ...                         ...
# 23757                Ana BOBIER
# 23758                Ana BOBIER
# 23759           Annabelle OSTYN
# 23760  Géraldine BLEMAND-JEANNE
# 23761                Ana BOBIER
#
#                                            Contacts DR&I Numero projet  \
# 0                                           Enric THOMAS      P24/0956
# 1                                         Alice JANNIAUD      P22/0030
# 2                                       Alexandre MENARD      P25/0182
# 3                       Nicole PARIS // Chloé GRANDO-GAI      P25/0181
# 4                                         Hugo LE GARREC      P25/0180
# ...                                                  ...           ...
# 23757                                         Ana BOBIER      P14/0008
# 23758  Odile CYPRIA // Ana BOBIER // Meryem YALBIR //...      P14/0006
# 23759  Odile CYPRIA // Annabelle OSTYN // Lucie SALVA...      P14/0004
# 23760  Géraldine BLEMAND-JEANNE // Meryem YALBIR // E...      P14/0001
# 23761                     Ana BOBIER // Elsa TSOUBASSAKA      P14/0003
#
#                                          Intitule projet  \
# 0      Design of original Silicon-based multielement ...
# 1      Contrôle quantique performante des rotations m...
# 2      Fourier methods for a Eulerian-based contact m...
# 3                        NDA avec Multinationale Corning
# 4                              CIFRE_Withings_INRIA_LPSM
# ...                                                  ...
# 23757  Accord de confidentialité pour production de p...
# 23758                       Effet du V55 sur les plantes
# 23759                                    med-hiss Life +
# 23760                                     PIA - HEPATHER
# 23761  accord confidentialité pour communiqué presse ...
#
#                                 Acronyme                  Type projet  \
# 0                                SILICOR        Activité de recherche
# 1                                 CoRoMo        Activité de recherche
# 2      Convention d'accueil Flavio Lorez        Activité de recherche
# 3                                  néant        Activité de recherche
# 4                                  CIFRE  Mission formation recherche
# ...                                  ...                          ...
# 23757                                NaN        Activité de recherche
# 23758                                NaN       Activité de prestation
# 23759                            Medhiss        Activité de recherche
# 23760                           HEPATHER               Infrastructure
# 23761                            NR test               Activité de PI
#
#       Cadre de financement  ...  \
# 0           Horizon Europe  ...
# 1            ANR opérateur  ...
# 2              Autre cadre  ...
# 3                      NaN  ...
# 4                     ANRT  ...
# ...                    ...  ...
# 23757          Autre cadre  ...
# 23758                  NaN  ...
# 23759             Hors FP7  ...
# 23760                  PIA  ...
# 23761                  NaN  ...
#
#                                       Acteurs::Sous-type  \
# 0                                  Commission européenne
# 1            Opérateurs de recherche // Conseil régional
# 2                                Opérateurs de recherche
# 3      Grandes entreprises, Plus de 1500 millions d'€...
# 4      Opérateurs de recherche // Petites et moyennes...
# ...                                                  ...
# 23757                            Opérateurs de recherche
# 23758  Grandes entreprises, Plus de 1500 millions d'€...
# 23759  Opérateurs de recherche // Commission européen...
# 23760  Opérateurs de recherche // Agences // Agences ...
# 23761  Petites et moyennes entreprises (PME), Moins d...
#
#                                          Acteurs::Classe  \
# 0                                                    NaN
# 1      Organismes de recherche à but non lucratif (EP...
# 2                                            UNIVERSITE
# 3                                                    NaN
# 4      Organismes de recherche à but non lucratif (EP...
# ...                                                  ...
# 23757             Autres établissements publics (EPA...)
# 23758                                                NaN
# 23759  Organismes de recherche à but non lucratif (EP...
# 23760  Organismes de recherche à but non lucratif (EP...
# 23761                                                NaN
#
#                                            Acteurs::Pays  \
# 0                                               Belgique
# 1                                       France // France
# 2                                                 SUISSE
# 3                                                 France
# 4                                       France // France
# ...                                                  ...
# 23757                                             France
# 23758                                             France
# 23759  France // Belgique // ITALIE // ESPAGNE // ITA...
# 23760             France // France // France // Belgique
# 23761                                                USA
#
#                                 Financeurs::Dénomination  \
# 0                                  Commission Européenne
# 1                         CONSEIL REGIONAL ILE DE FRANCE
# 2                                                    NaN
# 3                                                    NaN
# 4                                               Withings
# ...                                                  ...
# 23757                                                NaN
# 23758                                           LESAFFRE
# 23759                              Commission Européenne
# 23760  Agence Nationale de la Recherche // AGENCE NAT...
# 23761                                                NaN
#
#            Financeurs::Sigle                          Financeurs::Type  \
# 0      Commission Européenne               Organisation Internationale
# 1                     CR IdF               Collectivités territoriales
# 2                        NaN                                       NaN
# 3                        NaN                                       NaN
# 4                   Withings                               Entreprises
# ...                      ...                                       ...
# 23757                    NaN                                       NaN
# 23758               LESAFFRE                               Entreprises
# 23759  Commission Européenne               Organisation Internationale
# 23760            ANR // ANRS  Recherche publique // Recherche publique
# 23761                    NaN                                       NaN
#
#                                    Financeurs::Sous-type  \
# 0                                  Commission européenne
# 1                                       Conseil régional
# 2                                                    NaN
# 3                                                    NaN
# 4      Petites et moyennes entreprises (PME), Moins d...
# ...                                                  ...
# 23757                                                NaN
# 23758  Grandes entreprises, Plus de 1500 millions d'€...
# 23759                              Commission européenne
# 23760                                 Agences // Agences
# 23761                                                NaN
#
#                                       Financeurs::Classe  Financeurs::Pays  \
# 0                                                    NaN          Belgique
# 1                                                    NaN            France
# 2                                                    NaN               NaN
# 3                                                    NaN               NaN
# 4                                                    NaN            France
# ...                                                  ...               ...
# 23757                                                NaN               NaN
# 23758                                                NaN            France
# 23759                                                NaN          Belgique
# 23760  en charge de la recherche // en charge de la r...  France // France
# 23761                                                NaN               NaN
#
#        Year
# 0      2025
# 1      2025
# 2      2025
# 3      2025
# 4      2025
# ...     ...
# 23757  2014
# 23758  2014
# 23759  2014
# 23760  2014
# 23761  2014
#
# [23762 rows x 52 columns]

# %%
import plotly.express as px

# %%
filtered_df = df[df['Financeurs::Pays'].isin(value_counts[value_counts > 10].index)]

# Group by Category and sum Values
grouped_df = filtered_df.groupby("Category", as_index=False)["Values"].sum()

# Create Interactive Bar Plot
fig = px.bar(grouped_df, x="Category", y="Values", 
             title="Grouped Data Bar Plot",
             text_auto=True,  # Show values on bars
             color="Category")  # Different color per category

# Display in Streamlit
st.write("### Interactive Bar Plot")
st.plotly_chart(fig)

# %%
occurences["Phase"].index
occurences.columns[0]
# Out:
# 'Phase'

# %%
# 		       Phase
# Outil du cadre	        Phase	
# CDDP	en gestion	        12
#       en négociation	    6
# CIFRE	archivé	            61
#       en gestion	        272
#       en négociation	    91
#       en préparation	    25

# get all the possible lo levl values 
lowLevelVar=occurences.columns[0]
possible_status=list(set([ x[1] for x in occurences[lowLevelVar].index]))
display_dict={}
# iterate through a dataframe
for index, row in occurences.iterrows():
    highLevel=index[0]
    lowLevel =index[1]
    if highLevel not in display_dict:
        display_dict[highLevel]=[0]*len(possible_status) # initialize the count list
        lowLevelIndex=possible_status.index(lowLevel)
        assert lowLevelIndex>=0 and lowLevelIndex<len(possible_status)
        display_dict[highLevel][lowLevelIndex]=int(row[lowLevelVar])
    else : 
        lowLevelIndex=possible_status.index(lowLevel)
        assert lowLevelIndex>=0 and lowLevelIndex<len(possible_status)
        display_dict[highLevel][lowLevelIndex]=int(row[lowLevelVar])
display_dict

message=""
for k,v in display_dict.items():
    message+=f"{k} \n"
    for i,e in enumerate(v):
        message+=f"\t{possible_status[i]} : {e} \n"
        
message
# Out:
# 'CDDP \n\ten préparation : 0 \n\tarchivé : 0 \n\ten gestion : 12 \n\ten négociation : 6 \nCIFRE \n\ten préparation : 25 \n\tarchivé : 61 \n\ten gestion : 272 \n\ten négociation : 91 \n'
